# %%
import pandas as pd

# %%
df=pd.read_csv("jsrt_metadata.csv")

# %%
df.head(n=247)
# Out:
#          study_id  subtlety  size age  gender       x       y       state  \
# 0    JPCLN001.png       5.0  15.0  53    Male  1634.0   692.0   malignant
# 1    JPCLN002.png       5.0  30.0  78  Female  1614.0  1090.0      benign
# 2    JPCLN003.png       5.0  30.0  63  Female  1303.0   447.0   malignant
# 3    JPCLN004.png       5.0  14.0  68  Female   606.0   836.0      benign
# 4    JPCLN005.png       5.0  35.0  73  Female  1438.0   692.0   malignant
# ..            ...       ...   ...  ..     ...     ...     ...         ...
# 242  JPCNN089.png       NaN   NaN  50    Male     NaN     NaN  non-nodule
# 243  JPCNN090.png       NaN   NaN  68  Female     NaN     NaN  non-nodule
# 244  JPCNN091.png       NaN   NaN  81    Male     NaN     NaN  non-nodule
# 245  JPCNN092.png       NaN   NaN  70  Female     NaN     NaN  non-nodule
# 246  JPCNN093.png       NaN   NaN  41    Male     NaN     NaN  non-nodule
#
#                position           diagnosis
# ...

# %%
import numpy as np
df.replace("?", np.nan, inplace=True)
df
# Out:
#          study_id  subtlety  size age  gender       x       y       state  \
# 0    JPCLN001.png       5.0  15.0  53    Male  1634.0   692.0   malignant
# 1    JPCLN002.png       5.0  30.0  78  Female  1614.0  1090.0      benign
# 2    JPCLN003.png       5.0  30.0  63  Female  1303.0   447.0   malignant
# 3    JPCLN004.png       5.0  14.0  68  Female   606.0   836.0      benign
# 4    JPCLN005.png       5.0  35.0  73  Female  1438.0   692.0   malignant
# ..            ...       ...   ...  ..     ...     ...     ...         ...
# 242  JPCNN089.png       NaN   NaN  50    Male     NaN     NaN  non-nodule
# 243  JPCNN090.png       NaN   NaN  68  Female     NaN     NaN  non-nodule
# 244  JPCNN091.png       NaN   NaN  81    Male     NaN     NaN  non-nodule
# 245  JPCNN092.png       NaN   NaN  70  Female     NaN     NaN  non-nodule
# 246  JPCNN093.png       NaN   NaN  41    Male     NaN     NaN  non-nodule
#
#                position           diagnosis
# ...

# %%
import matplotlib as plt
from matplotlib import pyplot
df.head(n=154)
# Out:
#          study_id  subtlety  size age  gender       x       y      state  \
# 0    JPCLN001.png       5.0  15.0  53    Male  1634.0   692.0  malignant
# 1    JPCLN002.png       5.0  30.0  78  Female  1614.0  1090.0     benign
# 2    JPCLN003.png       5.0  30.0  63  Female  1303.0   447.0  malignant
# 3    JPCLN004.png       5.0  14.0  68  Female   606.0   836.0     benign
# 4    JPCLN005.png       5.0  35.0  73  Female  1438.0   692.0  malignant
# ..            ...       ...   ...  ..     ...     ...     ...        ...
# 149  JPCLN150.png       1.0  15.0  51  Female  1544.0  1409.0  malignant
# 150  JPCLN151.png       1.0  14.0  37  Female  1520.0  1364.0  malignant
# 151  JPCLN152.png       1.0  10.0  56    Male  1323.0  1438.0     benign
# 152  JPCLN153.png       1.0  10.0  64    Male  1708.0  1122.0  malignant
# 153  JPCLN154.png       1.0   8.0  75  Female   660.0   688.0  malignant
#
#                position                     diagnosis
# ...

# %%
df['diagnosis'].value_counts()
# Out:
# lung cancer                                       56
# lung cancer(adenocarcinoma)                       23
# tuberculoma                                       14
# granuloma                                          8
# lung cancer(bronchioloalveolar cell carcinoma)     7
# unknown                                            4
# metastasis of colon cancer                         4
# inflammatory mass                                  4
# pulmonary tuberculosis                             3
# lung abscess                                       2
# Cryptococcosis                                     2
# lung cancer(squamous cell carcinoma)               2
# Inflammatory mass                                  2
# pulmonary hematoma                                 2
# susp. inflammatory mass                            2
# hamartoma                                          2
# sclerosing hemangioma                              2
# lung cancer(large cell carcinoma)                  1
# ...

# %%
import matplotlib as plt
from matplotlib import pyplot
plt.pyplot.title('histogram')
plt.pyplot.ylabel('Patients')
plt.pyplot.xlabel('deseases')
plt.pyplot.hist(df['diagnosis'].value_counts())
# Out:
# (array([27.,  2.,  1.,  0.,  1.,  0.,  0.,  0.,  0.,  1.]),
#  array([ 1. ,  6.5, 12. , 17.5, 23. , 28.5, 34. , 39.5, 45. , 50.5, 56. ]),
#  <BarContainer object of 10 artists>)

# %%
df.isnull().sum()
# Out:
# study_id      0
# subtlety     93
# size         93
# age           2
# gender        0
# x            93
# y            93
# state         0
# position     93
# diagnosis    93
# dtype: int64

# %%
s=df['state'].value_counts()

# %%
s
# Out:
# malignant     100
# non-nodule     93
# benign         54
# Name: state, dtype: int64

# %%
plt.pyplot.pie(df['state'].value_counts(),labels=['malignant','non-nodule','benign'],autopct=lambda x: '{:.0f}'.format(x*s.sum()/100))
# Out:
# ([<matplotlib.patches.Wedge at 0x16a55329790>,
# ...
#  [Text(0.32391238769004677, 1.051228217420429, 'malignant'),
#   Text(-0.9170384122918548, -0.607487078365651, 'non-nodule'),
#   Text(0.8505887820229197, -0.6974946049230534, 'benign')],
#  [Text(0.17667948419457094, 0.5733972095020522, '100'),
#   Text(-0.5002027703410117, -0.3313565881994459, '93'),
#   Text(0.46395751746704705, -0.3804516026853018, '54')])

# %%
g=df['gender'].value_counts()

# %%
g
# Out:
# Female    128
# Male      119
# Name: gender, dtype: int64

# %%
plt.pyplot.pie(df['gender'].value_counts(),labels=['Female','Male'],autopct=lambda x: '{:.0f}'.format(x*g.sum()/100))
# Out:
# ([<matplotlib.patches.Wedge at 0x16a5537e520>,
# ...
#  [Text(-0.06292471903937313, 1.098198743276378, 'Female'),
#   Text(0.06292471903937276, -1.098198743276378, 'Male')],
#  [Text(-0.03432257402147625, 0.5990174963325697, '128'),
#   Text(0.034322574021476045, -0.5990174963325697, '119')])
